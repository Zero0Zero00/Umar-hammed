# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
#Performing data exploaration by importing the dataset and also viewing the first 100 rows of the dataset
df = pd.read_csv ('C:\\Users\\Sadiq Muhd Sani Jega/\Downloads\/ames.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#describe the dtaaframe summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Describe the descriptive statistic of the dataset
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# df.shape

# %%
#PERFORMING DATA CLEANING
missing_values = df.isnull().any().any()

# %%
print (missing_values)
# Out:
# True

# %%
#Removing the missing val
removing_missing= df.dropna()

# %%
#DATA VISUALIZATION
# Plotting the histogram for the target variable (SalePrice)
plt.figure(figsize=(10, 6))
sns.histplot(df['SalePrice'], kde=True)
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.title('Distribution of SalePrice')
plt.show()

# %%
#PLOTING CORRELATION HEAT MAP AND MATRIX

# Calculating the correlation matrix
correlation_matrix = df.corr()

# Plotting the correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
#PERFORMING FEATURE ENGINEERING
import pandas as pd

# Create the new feature 'TotalSF'
df['TotalSF'] = df['1stFlrSF'] + df['2ndFlrSF'] + df['TotalBsmtSF']

# Display the first few rows of the DataFrame to check the new feature
print(df[['1stFlrSF', '2ndFlrSF', 'TotalBsmtSF', 'TotalSF']].head())
# Out:
#    1stFlrSF  2ndFlrSF  TotalBsmtSF  TotalSF
# 0       856       854          856     2566
# 1      1262         0         1262     2524
# 2       920       866          920     2706
# 3       961       756          756     2473
# 4      1145      1053         1145     3343

# %%
#DATA ANALYSIS

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Select the target variable column (SalePrice) from the correlation matrix
target_correlation = correlation_matrix['SalePrice']

# %%
# Display features with strong negative correlation
strong_negative_corr_features = target_correlation[target_correlation < -0.5]
print("Features with strong negative correlation:")
print(strong_negative_corr_features)
# Out:
# Features with strong negative correlation:
# Series([], Name: SalePrice, dtype: float64)

# %%
# Display features with strong positive correlation
strong_positive_corr_features = target_correlation[target_correlation > 0.5]
print("Features with strong positive correlation:")
print(strong_positive_corr_features)
# Out:
# Features with strong positive correlation:
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# GrLivArea       0.708624
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# GarageCars      0.640409
# GarageArea      0.623431
# SalePrice       1.000000
# TotalSF         0.782260
# Name: SalePrice, dtype: float64
